# %%
# impotação biblioteca 
import pandas as pd

# %%
# Chamando o banco de dados
dados = pd.read_csv('C:\\Users\\david\\Date_Science\\Cientista de Dados Python para Iniciantes\dataset\\data.csv')

# %%
# visualisar dados
dados
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
# visualizados os 5 primeiros dados
dados.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
# visualizados os 5 ultimos dados  
dados.tail()
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# ...

# %%
# visualizados os 2 primeiros   
dados.head(2)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
#
#                                   Flag  Overall  Potential          Club  ...  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94  FC Barcelona  ...
# 1  https://cdn.sofifa.org/flags/38.png       94         94      Juventus  ...
#
#   Composure Marking StandingTackle  SlidingTackle GKDiving  GKHandling  \
# 0      96.0    33.0           28.0           26.0      6.0        11.0
# 1      95.0    28.0           31.0           23.0      7.0        11.0
#
#    GKKicking  GKPositioning GKReflexes Release Clause
# 0       15.0           14.0        8.0        €226.5M
# 1       15.0           14.0       11.0        €127.1M
#
# ...

# %%
# Quais as colunas
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
# Resumo de dados
dados.index
# Out:
# RangeIndex(start=0, stop=18207, step=1)

# %%
# inspecionar apenas uma coluna
dados['Name']
# Out:
# 0                  L. Messi
# 1         Cristiano Ronaldo
# 2                 Neymar Jr
# 3                    De Gea
# 4              K. De Bruyne
#                 ...
# 18202          J. Lundstram
# 18203    N. Christoffersson
# 18204             B. Worman
# 18205        D. Walker-Rice
# 18206             G. Nugent
# Name: Name, Length: 18207, dtype: object

# %%
# selecinar colunas
dados[['Name', 'Wage', 'Nationality']]
# Out:
#                      Name   Wage Nationality
# 0                L. Messi  €565K   Argentina
# 1       Cristiano Ronaldo  €405K    Portugal
# 2               Neymar Jr  €290K      Brazil
# 3                  De Gea  €260K       Spain
# 4            K. De Bruyne  €355K     Belgium
# ...                   ...    ...         ...
# 18202        J. Lundstram    €1K     England
# 18203  N. Christoffersson    €1K      Sweden
# 18204           B. Worman    €1K     England
# 18205      D. Walker-Rice    €1K     England
# 18206           G. Nugent    €1K     England
#
# [18207 rows x 3 columns]

# %%
# Localizar por colunas : linhas
dados.iloc[0:4]
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# ...

# %%
# Localizar dados dentro da colunas : linhas
dados.iloc[2,2]
# Out:
# 'Neymar Jr'

# %%
# Filtar por colunas dados da coluna
dados.loc[dados['Nationality'] == 'Argentina']
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 0               0  158023        L. Messi   31
# 15             15  211110       P. Dybala   24
# 23             23  153079       S. Agüero   30
# 38             38  167664      G. Higuaín   30
# 43             43  201399       M. Icardi   25
# ...           ...     ...             ...  ...
# 17349       17349  240955        T. Durso   19
# 17355       17355  237125      V. Barbero   17
# 17638       17638  236431      E. Alarcón   25
# 17861       17861  245726   F. Bustamante   19
# 17987       17987  241099  L. Finochietto   21
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 15     https://cdn.sofifa.org/players/4/19/211110.png   Argentina
# 23     https://cdn.sofifa.org/players/4/19/153079.png   Argentina
# 38     https://cdn.sofifa.org/players/4/19/167664.png   Argentina
# ...

# %%
# Filtar por colunas dados da coluna
dados.loc[dados['Age'] == 21]
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 155           155  231443      O. Dembélé   21
# 156           156  230666   Gabriel Jesus   21
# 228           228  230658          Arthur   21
# 234           234  224411  Gonçalo Guedes   21
# 236           236  222737          Malcom   21
# ...           ...     ...             ...  ...
# 18112       18112  239857       Chen Zhao   21
# 18116       18116  243709    K. Moesgaard   21
# 18138       18138  243097     Yin Congyao   21
# 18147       18147  225510       D. Mackay   21
# 18167       18167  243112          Wu Lei   21
#
#                                                 Photo Nationality  \
# 155    https://cdn.sofifa.org/players/4/19/231443.png      France
# 156    https://cdn.sofifa.org/players/4/19/230666.png      Brazil
# 228    https://cdn.sofifa.org/players/4/19/230658.png      Brazil
# 234    https://cdn.sofifa.org/players/4/19/224411.png    Portugal
# ...

# %%
# buscar dados por coluna (filtra os mais novos é os mais velhos)
dados.sort_values('Age')
# Out:
#        Unnamed: 0      ID           Name  Age  \
# 18206       18206  246269      G. Nugent   16
# 17743       17743  244752      J. Olstad   16
# 13293       13293  246594    H. Massengo   16
# 16081       16081  241552    J. Italiano   16
# 18166       18166  243621       N. Ayéva   16
# ...           ...     ...            ...  ...
# 12192       12192  208927   H. Sulaimani   41
# 10545       10545  140183    S. Narazaki   42
# 18183       18183   53748  K. Pilkington   44
# 17726       17726   51963      T. Warner   44
# 4741         4741  140029       O. Pérez   45
#
#                                                 Photo        Nationality  \
# 18206  https://cdn.sofifa.org/players/4/19/246269.png            England
# 17743  https://cdn.sofifa.org/players/4/19/244752.png             Norway
# 13293  https://cdn.sofifa.org/players/4/19/246594.png             France
# 16081  https://cdn.sofifa.org/players/4/19/241552.png          Australia
# ...

# %%
# buscar dados por coluna (filtran pelas ultmas letra do alfabeto para as primeiras)
dados.sort_values('Name', ascending= False)
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 10002       10002  220433   Óscar Whalley   24
# 10353       10353  243558  Óscar Valentín   23
# 2564         2564  208621     Óscar Plano   27
# 9803         9803  229865    Óscar Pinchi   22
# 15334       15334  246284       Óscar Gil   20
# ...           ...     ...             ...  ...
# 12816       12816  245438   A. Abdu Jaber   21
# 6388         6388  138698         A. Abdi   31
# 3055         3055  198076    A. Abdennour   28
# 15665       15665  243896   A. Abdellaoui   25
# 13632       13632  228006        A. Abang   21
#
#                                                 Photo  Nationality  \
# 10002  https://cdn.sofifa.org/players/4/19/220433.png        Spain
# 10353  https://cdn.sofifa.org/players/4/19/243558.png        Spain
# 2564   https://cdn.sofifa.org/players/4/19/208621.png        Spain
# 9803   https://cdn.sofifa.org/players/4/19/229865.png        Spain
# ...

# %%
# buscar dados por coluna (filtran colunas ordem decresente)
dados.sort_values(['Name', 'Age'])
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 13632       13632  228006        A. Abang   21
# 15665       15665  243896   A. Abdellaoui   25
# 3055         3055  198076    A. Abdennour   28
# 6388         6388  138698         A. Abdi   31
# 12816       12816  245438   A. Abdu Jaber   21
# ...           ...     ...             ...  ...
# 15334       15334  246284       Óscar Gil   20
# 9803         9803  229865    Óscar Pinchi   22
# 2564         2564  208621     Óscar Plano   27
# 10353       10353  243558  Óscar Valentín   23
# 10002       10002  220433   Óscar Whalley   24
#
#                                                 Photo  Nationality  \
# 13632  https://cdn.sofifa.org/players/4/19/228006.png     Cameroon
# 15665  https://cdn.sofifa.org/players/4/19/243896.png      Algeria
# 3055   https://cdn.sofifa.org/players/4/19/198076.png      Tunisia
# 6388   https://cdn.sofifa.org/players/4/19/138698.png  Switzerland
# ...

# %%
# criar Coluna [total] com soma de tres colunas
dados['Total'] = dados['Acceleration'] + dados['Agility'] + dados['Reactions']
dados
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
# coluna criada [total] com coluna nomes
dados = dados[['Name', 'Total']]
dados.sort_values('Total', ascending = False)
# Out:
#                  Name  Total
# 2           Neymar Jr  284.0
# 5           E. Hazard  279.0
# 0            L. Messi  277.0
# 26           M. Salah  276.0
# 50         D. Mertens  275.0
# ...               ...    ...
# 13279    P. Mazzocchi    NaN
# 13280       Y. Ammour    NaN
# 13281  Jwa Joon Hyeop    NaN
# 13282      O. Marrufo    NaN
# 13283     Han Pengfei    NaN
#
# [18207 rows x 2 columns]

# %%
# exportando dados csv
dados.to_csv('Results/dados1.csv', index=False)

# %%
# exportando dados xlsx
dados.to_excel('Results/dados1.xlsx', index=False)

# %%
# exportando dados txt
dados.to_csv('Results/dados3.txt', index= False, sep='\t')
